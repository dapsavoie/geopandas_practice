# %%
import geopandas as gpd 
import pandas as pd
import matplotlib.pyplot as plt

# %%
ke = gpd.read_file('C:/Users/Manjari Prashar/Desktop/County/County/County.shp')

# %%
ke.head()
# Out:
#    fid  OBJECTID   ID        Name Code  Shape_Leng  Shape_Area          Area  \
# 0  1.0       1.0  1.0     Mombasa  MBA    0.885586    0.023325  2.864232e+08
# 1  2.0       2.0  2.0       Kwale  KLE    4.284182    0.758266  9.309279e+09
# 2  3.0       3.0  3.0      Kilifi  KLF    5.333080    1.025338  1.260187e+10
# 3  4.0       4.0  4.0  Tana River  TAN   10.280449    3.184213  3.917746e+10
# 4  5.0       5.0  5.0        Lamu  LAU    3.744689    0.743743  9.148879e+09
#
#                                             geometry
# 0  POLYGON ((39.68250 -4.05829, 39.68292 -4.05579...
# 1  POLYGON ((39.32031 -3.56799, 39.31873 -3.57269...
# 2  POLYGON ((39.71051 -3.90869, 39.71393 -3.90509...
# 3  POLYGON ((39.02753 -0.00153, 39.03168 -0.00171...
# 4  POLYGON ((41.07727 -2.38000, 40.99213 -2.44751...

# %%
ke.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
ke['Shape_Area'] = ke.Shape_Area

# %%
ke_crs = ke.crs

ke.to_crs(epsg=3857, inplace=True)

ke.plot(column='Area', cmap ='jet', legend_kwds ={'label': "Area of Country"}, figsize=(7,7))
# Out:
# <AxesSubplot:>
