# %%
import geopandas as gpd

# %%
croplands =  gpd.read_file('C:/Users/Manjari Prashar/Desktop/ke_agriculture/ke_agriculture.shp')

# %%
croplands.head()
# Out:
#     AGID                                         AGRICULTUR  \
# 0  AG-1C  Isolated (in natural vegetation or other) Rain...
# 1  AG-1B  Scattered (in natural vegetation or other) Rai...
# 2  AG-1C  Isolated (in natural vegetation or other) Rain...
# 3  AG-1C  Isolated (in natural vegetation or other) Rain...
# 4  AG-1B  Scattered (in natural vegetation or other) Rai...
#
#                                             geometry
# 0  POLYGON ((34.20743 4.39135, 34.20744 4.39136, ...
# 1  POLYGON ((40.68834 4.23472, 40.69033 4.23493, ...
# 2  POLYGON ((40.61968 4.21145, 40.64981 4.22397, ...
# 3  POLYGON ((34.33807 4.21732, 34.34047 4.21690, ...
# 4  POLYGON ((40.58221 4.19588, 40.61968 4.21145, ...

# %%
croplands.columns
# Out:
# Index(['AGID', 'AGRICULTUR', 'geometry'], dtype='object')

# %%
# visualize shapefiles in python 
import matplotlib.pyplot as plt

# %% [markdown]
# #  Plot Shapefiles

# %%
croplands.plot()

# %%
len(croplands)
# Out:
# 2260

# %%
croplands.plot(cmap = 'jet', column = 'AGRICULTUR', figsize = (20,20))

# %%
gpd.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
gpd.datasets.get_path('naturalearth_lowres')
# Out:
# 'C:\\Anaconda\\envs\\geopandas_env\\lib\\site-packages\\geopandas\\datasets\\naturalearth_lowres\\naturalearth_lowres.shp'

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
ke = world[world.name == 'Kenya']

# %%
ke.plot(figsize =(20,20))

# %%
map_with_crop = gpd.sjoin(croplands, ke, how="inner", op='intersects')

# %%
map_with_crop.plot(figsize=(20,20))
